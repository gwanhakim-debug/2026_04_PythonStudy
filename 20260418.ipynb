# %%
todo = {}
while True:
    print("\n[메뉴]")
    print("1. 할 일 추가")
    print("2. 완료 처리")
    print("3. 전체 보기")
    print("4. 종료")
    menu = input("메뉴 선택: ")
    if menu == '1':
        task = input("할 일 입력: ")
        todo[task] = False
        print("추가 완료!")
    
    elif menu == '2':          # ← 들여쓰기 1칸 너무 많았음
        task = input("완료할 일 입력: ")
        if task in todo:
            todo[task] = True  # ← 완료 처리 코드 빠져있었음!
            print("완료 처리!")
        else:
            print("없는 할 일입니다.")
    
    elif menu == '3':
        if not todo:
            print("할 일이 없습니다.")
        else:
            print("\n[TODO LIST]")
            for t, done in todo.items():
                if done:
                    status = "O"
                else:
                    status = "X"
                print(f"{t} : {status}")  # ← Print → print 소문자
    elif menu == '4':
        print("프로그램 종료")
        break
    else:
        print("잘못된 입력입니다.")

# %%
#a = List()
a = []
print(type(a))
a = [a,'SDG',True]
print(a)
print(a[1],a[0:2])
# Out:
# <class 'list'>
# [[], 'SDG', True]
# SDG [[], 'SDG']

# %%
t1 = (1,2)
print(type(t1))
print(t1)
# Out:
# <class 'tuple'>
# (1, 2)

# %% [raw]
# dic = {"홍길동": 90, "김순이": 80}
# print(dic)
# for k in dic.keys():
#     print(k)
# for v in dic.items():
#     print(v)
# for k, v in dic.items():
#     print(k,v)
# dic["김하나"] = 89
# del dic["김순이"]
# dic["홍길동"] = 100
# print(dic)
# if "김하나" in dic:
#     print("있어요")

# %%
list2 = [1,2,2,2,3,3,3,3,3,1]
s1 = set(list2)
print(s1, type(s1))
list1 = list(s1)
print(list1)
# Out:
# {1, 2, 3} <class 'set'>
# [1, 2, 3]

# %%
a = 100
A = 200
b = True
print(a,A,b)
print(bool(0), bool(''))
print(bool('abc'))
# Out:
# 100 200 True
# False False
# True

# %%
abc = [[1, 2, 3], #행렬, 이차원(대괄호) 안에 이차원 리스트 형태
       [4, 5, 6],
       [7, 8, 9]]
#반복문을 사용하여 abc리스트의 모든 자료를 각각 출력하세요.
for x in abc:
    for y in x:
        print(y)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
card = [['2020/03/04', '주식회사 카카오페이', 1000],
        ['2020/03/03', '네이버페이', 51100],
        ['2020/03/02', '스타벅스코리아', 10000],
        ['2020/03/01', '11번가', 27500],
        ['2020/02/26', '주식회사 카카오페이', 32500],
        ['2020/02/26', '주식회사 카카오페이', 32500],
        ['2020/02/22', 'G마켓', 81500],
        ['2020/02/22', '네이버페이',131000]]
print(card)

#print(card[0][1])
#print(card[3][1])
for company in card:
    print(company[1])

#카드비용의 총액을 출력하시오.

s= 0
for cost in card:
    #print(cost[2])
    #s = s + cost[2]
    s += cost[2]
print("총 사용 금액", s)
# Out:
# [['2020/03/04', '주식회사 카카오페이', 1000], ['2020/03/03', '네이버페이', 51100], ['2020/03/02', '스타벅스코리아', 10000], ['2020/03/01', '11번가', 27500], ['2020/02/26', '주식회사 카카오페이', 32500], ['2020/02/26', '주식회사 카카오페이', 32500], ['2020/02/22', 'G마켓', 81500], ['2020/02/22', '네이버페이', 131000]]
# 주식회사 카카오페이
# 네이버페이
# 스타벅스코리아
# 11번가
# 주식회사 카카오페이
# 주식회사 카카오페이
# G마켓
# 네이버페이
# 총 사용 금액 367100

# %%
olympic =[[1, '미국', 46, 37, 38, 121],
          [2, '영국', 27, 23, 17, 67],
          [3, '중국', 26, 18, 26, 70],
          [4, '러시아', 19, 18, 19, 55],
          [5, '독일', 17, 10, 15, 42],
          [6, '일본', 12, 8, 21, 41],
          [7, '프랑스', 10, 18, 14, 42],
          [8, '대한민국', 9, 3, 9, 21]]
print(olympic[0][1], '금메달 개수:', olympic[0][2])
print(olympic[4][1], '금메달 개수:', olympic[4][2])
print(olympic[:4])
print(olympic[:4][1])

for row in olympic:
    print(row[:2])

print('금메달보다 은메달이 더 많은 나라')
for row in olympic:
    if row[2] < row[3]:
        print(row[1])

#이번에는 1위부터 8위까지 모든 국가가 획득한 금메달 개수의 합을 구해 봅시다.
total_gold = 0
for row in olympic:
    total_gold += row[2]
print(total_gold)

#나라별 총 메달 개수 중 금메달이 차지하는 비율이 40%가 넘는 나라를 구해 보겠습니다. 
for row in olympic:
    gold = row[2] / row[-1] * 100
    if gold > 40:
        print(row[1], gold, '%')
# Out:
# 미국 금메달 개수: 46
# 독일 금메달 개수: 17
# [[1, '미국', 46, 37, 38, 121], [2, '영국', 27, 23, 17, 67], [3, '중국', 26, 18, 26, 70], [4, '러시아', 19, 18, 19, 55]]
# [2, '영국', 27, 23, 17, 67]
# [1, '미국']
# [2, '영국']
# [3, '중국']
# [4, '러시아']
# [5, '독일']
# [6, '일본']
# [7, '프랑스']
# [8, '대한민국']
# 금메달보다 은메달이 더 많은 나라
# 프랑스
# 166
# 영국 40.298507462686565 %
# 독일 40.476190476190474 %
# 대한민국 42.857142857142854 %

# %%
#딕셔너리를 활용해 영단어장을 만들어 봅시다. 영단어장은 빈도수를 기준으로 빈도수가 높은 단어부터 낮은 단어순으로 정렬합니다.
#단어장은 『알리바바와 40인의 도적』1을 기반으로 만듭니다.

alibaba = " in a town of persia lived two brothers , sons of a poor man; one named cassim , the other alibaba . cassim , the elder…"
vocab = {}
word_list = alibaba.split()
print(word_list)
  
for w in word_list:          #word_list의 첫 단어부터 마지막 단어까지 반복하기
    if w not in vocab:       #단어가 vocab 딕셔너리의 키에 없으면 
        vocab[w] = 1         #vocab[단어] = 1
    else:                    #단어가 vocab 딕셔너리의 키에 있으면
        vocab[w] += 1        #vocab[단어] += 1
print(vocab)
# Out:
# ['in', 'a', 'town', 'of', 'persia', 'lived', 'two', 'brothers', ',', 'sons', 'of', 'a', 'poor', 'man;', 'one', 'named', 'cassim', ',', 'the', 'other', 'alibaba', '.', 'cassim', ',', 'the', 'elder…']
# {'in': 1, 'a': 2, 'town': 1, 'of': 2, 'persia': 1, 'lived': 1, 'two': 1, 'brothers': 1, ',': 3, 'sons': 1, 'poor': 1, 'man;': 1, 'one': 1, 'named': 1, 'cassim': 2, 'the': 2, 'other': 1, 'alibaba': 1, '.': 1, 'elder…': 1}

# %%
alibaba = " in a town of persia lived two brothers , sons of a poor man; one named cassim , the other alibaba . cassim , the elder…"
vocab = {}
for w in word_list:          #word_list의 첫 단어부터 마지막 단어까지 반복하기
    if w not in vocab:       #단어가 vocab 딕셔너리의 키에 없으면 
        vocab[w] = 1         #vocab[단어] = 1
    else:                    #단어가 vocab 딕셔너리의 키에 있으면
        vocab[w] += 1        #vocab[단어] += 1
print(vocab)

import operator
print(sorted(vocab.items(), key=operator.itemgetter(1), reverse=True))

#의미없는 단어 삭제
meaningless = ['.', ',', '!', '?', 'the', 'he', 'and', 'to', 'a', 'of', 'was', 'in', 'had', 'for', 'it', 'that', 'but', 'as', 'with', 'at', 'i', 'into', 'be', 'this', 'me', 'from', 'then', 'him', 'his', 'her', 'she', 'they', 'them', 'you']
for word in meaningless:
    if word in vocab:
        del vocab[word]
print(vocab)
# Out:
# {'in': 1, 'a': 2, 'town': 1, 'of': 2, 'persia': 1, 'lived': 1, 'two': 1, 'brothers': 1, ',': 3, 'sons': 1, 'poor': 1, 'man;': 1, 'one': 1, 'named': 1, 'cassim': 2, 'the': 2, 'other': 1, 'alibaba': 1, '.': 1, 'elder…': 1}
# [(',', 3), ('a', 2), ('of', 2), ('cassim', 2), ('the', 2), ('in', 1), ('town', 1), ('persia', 1), ('lived', 1), ('two', 1), ('brothers', 1), ('sons', 1), ('poor', 1), ('man;', 1), ('one', 1), ('named', 1), ('other', 1), ('alibaba', 1), ('.', 1), ('elder…', 1)]
# {'town': 1, 'persia': 1, 'lived': 1, 'two': 1, 'brothers': 1, 'sons': 1, 'poor': 1, 'man;': 1, 'one': 1, 'named': 1, 'cassim': 2, 'other': 1, 'alibaba': 1, 'elder…': 1}

# %%
import operator   #정렬 기능 사용하기

vocab_final = sorted(vocab.items(), key=operator.itemgetter(1), reverse=True)
              #딕셔너리를 짝꿍 목록으로 꺼내라
                                    #1번째 값 기준으로 정렬해 (횟수 컬럼으로 정렬)
                                                            #내림차순으로
print(vocab_final)
# Out:
# [('cassim', 2), ('town', 1), ('persia', 1), ('lived', 1), ('two', 1), ('brothers', 1), ('sons', 1), ('poor', 1), ('man;', 1), ('one', 1), ('named', 1), ('other', 1), ('alibaba', 1), ('elder…', 1)]

# %%
alibaba = """
There once lived two brothers named ali baba and cassim.
ali baba lived with his poor wife in a small house.
in other way, cassim lived in a big house because he married a rich girl.
cassim is selfish man and very greedy man.
so he didn't share his enough money with his brother.
alibaba earn money from selling woods to market.
someday, when alibaba went to forest to cut trees, he saw forty men were standing beside a large stone.
the leader of the group said in a loud voice "open sesame"
after that, the stone moved revealing a door way.
all of the men went inside the cave with th bags on their backs.
when they came out, the bags were filled with a lot of gold and jewels.
alibaba was suprised.
so he went to big stone after the group left.
and said "open sesame" 
so he could enter the cave, and he brought a lot of gold at that.
he told about it to his brother.
so cassim went to cave directly 
and he said, open sesame.
and he grabbed so many gold and decided to leave.
but he forgot the magic keyword to open the stone.
at that time, forty Theives came to the stone.
they found cassime in cave and cut him up into many pieces.
cassim's wife got worried abou her husband.
so she told about her husband to alibaba.
when alibaba heard about that he knew where his brother was, so he went to the cave.
he found his brother cut up into pieces.
he told cassim's wift that her husband had died. 
she cried and said i want to have husband.
so alibaba told her that he could marry her and be her husband.
then she would not be sad anymore and she agred to marry him.
alibaba and his two wieves lived happily ever after.
"""
vocab = {}
word_list = alibaba.split()
print(word_list)
# Out:
# ['There', 'once', 'lived', 'two', 'brothers', 'named', 'ali', 'baba', 'and', 'cassim.', 'ali', 'baba', 'lived', 'with', 'his', 'poor', 'wife', 'in', 'a', 'small', 'house.', 'in', 'other', 'way,', 'cassim', 'lived', 'in', 'a', 'big', 'house', 'because', 'he', 'married', 'a', 'rich', 'girl.', 'cassim', 'is', 'selfish', 'man', 'and', 'very', 'greedy', 'man.', 'so', 'he', "didn't", 'share', 'his', 'enough', 'money', 'with', 'his', 'brother.', 'alibaba', 'earn', 'money', 'from', 'selling', 'woods', 'to', 'market.', 'someday,', 'when', 'alibaba', 'went', 'to', 'forest', 'to', 'cut', 'trees,', 'he', 'saw', 'forty', 'men', 'were', 'standing', 'beside', 'a', 'large', 'stone.', 'the', 'leader', 'of', 'the', 'group', 'said', 'in', 'a', 'loud', 'voice', '"open', 'sesame"', 'after', 'that,', 'the', 'stone', 'moved', 'revealing', 'a', 'door', 'way.', 'all', 'of', 'the', 'men', 'went', 'inside', 'the', 'cave', 'with', 'th', 'bags', 'on', 'their', 'backs.', 'when', 'they', 'came', 'out,', 'the', 'ba
# ...

# %%
alibaba = """
There once lived two brothers named ali baba and cassim.
ali baba lived with his poor wife in a small house.
in other way, cassim lived in a big house because he married a rich girl.
cassim is selfish man and very greedy man.
so he didn't share his enough money with his brother.
alibaba earn money from selling woods to market.
someday, when alibaba went to forest to cut trees, he saw forty men were standing beside a large stone.
the leader of the group said in a loud voice "open sesame"
after that, the stone moved revealing a door way.
all of the men went inside the cave with th bags on their backs.
when they came out, the bags were filled with a lot of gold and jewels.
alibaba was suprised.
so he went to big stone after the group left.
and said "open sesame" 
so he could enter the cave, and he brought a lot of gold at that.
he told about it to his brother.
so cassim went to cave directly 
and he said, open sesame.
and he grabbed so many gold and decided to leave.
but he forgot the magic keyword to open the stone.
at that time, forty Theives came to the stone.
they found cassime in cave and cut him up into many pieces.
cassim's wife got worried abou her husband.
so she told about her husband to alibaba.
when alibaba heard about that he knew where his brother was, so he went to the cave.
he found his brother cut up into pieces.
he told cassim's wift that her husband had died. 
she cried and said i want to have husband.
so alibaba told her that he could marry her and be her husband.
then she would not be sad anymore and she agred to marry him.
alibaba and his two wieves lived happily ever after.
"""
for w in word_list:          #word_list의 첫 단어부터 마지막 단어까지 반복하기
    if w not in vocab:       #단어가 vocab 딕셔너리의 키에 없으면 
        vocab[w] = 1         #vocab[단어] = 1
    else:                    #단어가 vocab 딕셔너리의 키에 있으면
        vocab[w] += 1        #vocab[단어] += 1
print(vocab)
# Out:
# {'There': 1, 'once': 1, 'lived': 4, 'two': 2, 'brothers': 1, 'named': 1, 'ali': 2, 'baba': 2, 'and': 13, 'cassim.': 1, 'with': 4, 'his': 7, 'poor': 1, 'wife': 2, 'in': 5, 'a': 8, 'small': 1, 'house.': 1, 'other': 1, 'way,': 1, 'cassim': 3, 'big': 2, 'house': 1, 'because': 1, 'he': 15, 'married': 1, 'rich': 1, 'girl.': 1, 'is': 1, 'selfish': 1, 'man': 1, 'very': 1, 'greedy': 1, 'man.': 1, 'so': 8, "didn't": 1, 'share': 1, 'enough': 1, 'money': 2, 'brother.': 2, 'alibaba': 6, 'earn': 1, 'from': 1, 'selling': 1, 'woods': 1, 'to': 13, 'market.': 1, 'someday,': 1, 'when': 3, 'went': 5, 'forest': 1, 'cut': 3, 'trees,': 1, 'saw': 1, 'forty': 2, 'men': 2, 'were': 2, 'standing': 1, 'beside': 1, 'large': 1, 'stone.': 3, 'the': 12, 'leader': 1, 'of': 4, 'group': 2, 'said': 3, 'loud': 1, 'voice': 1, '"open': 2, 'sesame"': 2, 'after': 2, 'that,': 1, 'stone': 2, 'moved': 1, 'revealing': 1, 'door': 1, 'way.': 1, 'all': 1, 'inside': 1, 'cave': 3, 'th': 1, 'bags': 2, 'on': 1, 'their': 1, 'backs.': 1,
# ...

# %%
vocab_final = sorted(vocab.items(), key=operator.itemgetter(1), reverse=True)
print(vocab_final)
# Out:
# [('he', 15), ('and', 13), ('to', 13), ('the', 12), ('a', 8), ('so', 8), ('his', 7), ('alibaba', 6), ('her', 6), ('in', 5), ('went', 5), ('lived', 4), ('with', 4), ('of', 4), ('told', 4), ('that', 4), ('she', 4), ('cassim', 3), ('when', 3), ('cut', 3), ('stone.', 3), ('said', 3), ('cave', 3), ('gold', 3), ('about', 3), ('husband.', 3), ('two', 2), ('ali', 2), ('baba', 2), ('wife', 2), ('big', 2), ('money', 2), ('brother.', 2), ('forty', 2), ('men', 2), ('were', 2), ('group', 2), ('"open', 2), ('sesame"', 2), ('after', 2), ('stone', 2), ('bags', 2), ('they', 2), ('came', 2), ('lot', 2), ('could', 2), ('at', 2), ('open', 2), ('many', 2), ('found', 2), ('up', 2), ('into', 2), ('pieces.', 2), ("cassim's", 2), ('husband', 2), ('brother', 2), ('marry', 2), ('be', 2), ('There', 1), ('once', 1), ('brothers', 1), ('named', 1), ('cassim.', 1), ('poor', 1), ('small', 1), ('house.', 1), ('other', 1), ('way,', 1), ('house', 1), ('because', 1), ('married', 1), ('rich', 1), ('girl.', 1), ('is', 1), 
# ...

# %%
import matplotlib.pyplot as aa
aa.plot([1,2,3,4])
aa.show()

# %%
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
month = [3, 4, 5, 6, 7]
sales = [1, 5, 7, 3, 7]
plt.plot(month, sales)
plt.show()

# %%
import matplotlib.pyplot as plt
month = ['mar', 'apr', 'may', 'jun', 'jul']  #x축
sales = [1, 5, 7, 3, 7]                      #y축
plt.plot(month, sales)
plt.show()

# %%
import matplotlib.pyplot as plt
sales = [1, 5, 7, 3, 7]
month = ['mar', 'apr', 'may', 'jun', 'jul']
plt.rc('font', family='Malgun Gothic') # 글꼴 설정, macOS에서는 AppleGothic
plt.title('월별 판매 실적') # 그래프 제목 넣기
plt.plot(month, sales, color='g')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(dpi=150) # 그래프 크기 바꾸기
#plt.figure(figsize=(8, 4))
plt.rc('font', family='Malgun Gothic')
plt.title('월별 판매 실적')
plt.plot(month, sales, color='b')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.title('월별 판매 실적')
plt.plot(month, sales, color='b', label='단위: 개수') # 범례 넣기
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.title('월별 판매 실적')
plt.plot(month, sales, color='b', label='단위: 개수')
plt.legend(loc='lower right') #Upper 또는 center 쓰면 위치변경
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.title('월별 판매 실적')
plt.plot(month, sales, color='b', label='단위: 개수')
plt.legend(loc='lower right')
plt.xlabel('월')
plt.ylabel('매출')
plt.show()

# %%
import matplotlib.pyplot as plt

sales = [1, 5, 7, 3, 7]  #y축
month = [3, 4, 5, 6, 7]  #x축
plt.bar(month, sales)
plt.show()

# %%
import matplotlib.pyplot as plt
sales = [1, 5, 7, 3, 7]
#month = [3, 4, 5, 6, 7] = range(3,8)
plt.rc('font', family='Malgun Gothic')
plt.title('월별 판매 실적')
plt.bar(range(3, 8), sales, color='b')
plt.show()

# %%
import matplotlib.pyplot as plt
sales = [1, 5, 7, 3, 7]
plt.rc('font', family='Malgun Gothic')
plt.title('월별 판매 실적')
plt.bar(range(2, 11, 2), sales, color='b') #range: 2부터 시작, 11 전까지, 2씩 건너뛰어
plt.show()

# %%
import matplotlib.pyplot as plt
sales = [1, 5, 7, 3, 7]
plt.rc('font', family='Malgun Gothic')
plt.title('월별 판매 실적')
plt.barh(range(3, 8), sales, color='b') #range : 3부터 시작, 8 전까지, 1씩
plt.show()

# %%
import matplotlib.pyplot as plt
sales = [1, 5, 7, 3, 7]
plt.hist(sales) #히스토그램은 막대 모양의 도형으로 나타내는 그래프로, x축에는 데이터를, y축에는 데이터의 개수(빈도)를 넣어 분포를 표현합니다. 
plt.show()

# %%
import random
import matplotlib.pyplot as plt
a = []
for i in range(10): #random 값이 10개다
    a.append(random.randint(1, 10))
print(a)
plt.hist(a)
plt.show()
# Out:
# [1, 4, 7, 3, 10, 9, 9, 10, 10, 10]

# %%
import matplotlib.pyplot as plt #그래프 그려주는 라이브러리
b_type = [25, 19, 37, 11]
plt.pie(b_type) # 파이차트 그려줘
plt.show()

# %%
import matplotlib.pyplot as plt
b_type = [25, 19, 37, 11]
plt.rc('font', family='Malgun Gothic') # macOS에서는 'AppleGothic' ->한글 적용먼저 
plt.pie(b_type, labels=['A형', 'B형', 'O형', 'AB형']) #파이차트는 한글 적용 이후 작성
plt.show()

# %%
import matplotlib.pyplot as plt
b_type = [25, 19, 37, 11]
b_name = ['A형', 'B형', 'O형', 'AB형'] #변수처리 한것
plt.rc('font', family='Malgun Gothic')
plt.pie(b_type, labels=b_name)
plt.show()

# %%
import matplotlib.pyplot as plt
b_type = [25, 19, 37, 11]
b_name = ['A형', 'B형', 'O형', 'AB형']
plt.rc('font', family='Malgun Gothic')
plt.pie(b_type, labels=b_name, autopct='%1.1f%%') #%1.1f%%'는 소수점 첫째 자리까지, '%1.4f%%'는 소수점 넷째 자리까지 나타냅니다. 
plt.show()

# %%
f = open("새파일.txt", 'w')
for i in range(1,11):
    f.write(str(i*100) + "\n")
f.close()

# %%
f = open("새파일.txt", 'r')
line = f.readline()
print(line)
f.close()
# Out:
# 100

# %%
f = open("새파일.txt", 'r')
while True:
    line = f.readline()
    if not line:
        break
    print(line.strip()) #strip 함수로 한줄씩 떨어지지않게 표기
f.close()
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000

# %%
f = open("새파일.txt", 'r')
lines = f.readlines()
for line in lines:
    print(line.strip())
f.close()
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000

# %%
# CSV(Comma Separated Values) 파일은 쉼표(,)로 구분된 텍스트 형식의 파일

# %%
import csv
f = open(r"C:\Users\USER\python3ex\card.csv")
data = csv.reader(f)
data = list(data)
print(data)
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 2
#       1 import csv
# ----> 2 f = open(r"C:\Users\USER\python3ex\card.csv")
#       3 data = csv.reader(f)
#       4 data = list(data)
#       5 print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\USER\\python3ex\\card.csv'

# %%
import os
print(os.listdir(r"C:\Users\USER\python3ex"))
# Out:
# ['.claude', '.git', '.gitignore', '.ipynb_checkpoints', '20260404.ipynb', '20260404.py', '20260404teacher.ipynb', '20260411.ipynb', '20260418.ipynb', 'card.csv.csv', 'README_20260404.md', 'README_20260411.md', 'README_20260418.md', '새파일.txt']

# %%
import csv
f = open(r"C:\Users\USER\python3ex\card.csv", encoding='utf-8') #r은 "백슬래시 그대로 읽어줘" 라는 뜻
data = csv.reader(f)
next(data)
data = list(data)
print(data)
f.close()
# Out:
# [['2019-10-12 9:13', '1972753', '본', 'S&', '185', '네이버파이낸셜(주)', '546,800', '일시불(A)', '부분취소'], ['2019-10-12 11:56', '3399357', '본', 'S&', '185', 'GS  샵', '60,440', '일시불(A)', '전표매입'], ['2019-10-13 9:16', '12621902', '본', 'S&', '185', 'G마켓', '91,520', 'P(A)', '전표매입'], ['2019-10-14 1:32', '20726947', '본', 'S&', '185', '11번가', '89,810', '일시불(A)', '전표매입'], ['2019-10-14 7:06', '21234320', '본', 'S&', '185', '네이버파이낸셜(주)', '33,600', '일시불(A)', '전표매입'], ['2019-10-15 23:32', '42229559', '본', 'S&', '185', '네이버파이낸셜(주)', '309,600', '일시불(A)', '부분취소'], ['2019-10-16 8:00', '43433092', '본', 'S&', '185', 'SSG.COM', '61,983', '일시불(A)', '부분취소'], ['2019-10-16 16:04', '48341209', '본', 'S&', '185', '(주)에이랜드 타임스퀘어', '31,600', '일시불', '전표매입'], ['2019-10-17 1:13', '3495922', '본', 'S&', '185', '(주)어패럴컴퍼니', '97,000', '일시불(A)', '부분취소'], ['2019-10-17 20:19', '12252560', '본', 'S&', '185', '(주)곱', '96,000', '일시불', '전표매입'], ['2019-10-17 20:28', '12336385', '본', 'S&', '185', '카카오택시(선승인)', '4,200', '일시불', '승인취소'], ['2019-
# ...

# %%
import csv               # csv 라이브러리 포함하기

f = open('파일명.csv')   # 파일 열기
data = csv.reader(f)     # 파일 읽기
next(data)               # 표의 헤더 제거하기
data = list(data)        # 리스트로 변환하기
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 3
#       1 import csv               # csv 라이브러리 포함하기
#       2
# ----> 3 f = open('파일명.csv')   # 파일 열기
#       4 data = csv.reader(f)     # 파일 읽기
#       5 next(data)               # 표의 헤더 제거하기
#       6 data = list(data)        # 리스트로 변환하기
#
# FileNotFoundError: [Errno 2] No such file or directory: '파일명.csv'

# %%
import csv
f = open(r"C:\Users\USER\python3ex\card.csv", encoding='utf-8') #r은 "백슬래시 그대로 읽어줘" 라는 뜻
data = csv.reader(f)
next(data)
data = list(data)
print(data[0][0], data[0][5], data[0][6])
f.close()
# Out:
# 2019-10-12 9:13 네이버파이낸셜(주) 546,800

# %%
import csv
f = open(r"C:\Users\USER\python3ex\card.csv", encoding='utf-8') #r은 "백슬래시 그대로 읽어줘" 라는 뜻
data = csv.reader(f)
next(data)
data = list(data)
for row in data:
    print(row[6])
f.close()
# Out:
# 546,800
# 60,440
# 91,520
# 89,810
# 33,600
# 309,600
# 61,983
# 31,600
# 97,000
# 96,000
# 4,200
# 4,200
# 75,000
# 26,410
# 12,500
# 1,300
# 19,000
# 55,995
# 118,000
# 269,000
# 251,000
# 75,600
# 61,800
# 40,900
# 4,400
# 10,000
# 21,400
# 63,000
# 207,000
# 48,000
# 23,200
# 23,100
# 10,000
# 50,000
# 5,300
# 3,990
# 11,900
# 112,845
# 161,598
# 16,241
# 19,000
# 28,500
# 4,000
# 7,000
# 66,046
# 139,500
# 86,300
# 64,900
# 30,000
# 119,600
# 1,500
# 18,700
# 110,110
# 116,000
# 12,648
# 115,700
# 87,500
# 100
# 81,540
# 56,500
# 118,400
# 4,700
# 262,600
# 278,600
# 55,200
# 26,000
# 163,080
# 339,125
# 5,000
# 52,000
# 7,830
# 68,500
# 42,020
# 16,800
# 8,100
# 55,200
# 2,300
# 36,500
# 33,000
# 15,500
# 131,700
# 30,000
# 56,000
# 13,200
# 11,500
# 50,000
# 32,700
# 476,736
# 283,053
# 4,075
# 31,480
# 67,450
# 1,600
# 5,900
# 152,430
# 4,300
# 13,900
# 29,600
# 1,500
# 19,800
# 54,600
# 49,000
# 3,000
# 29,000
# 285,000
# 61,200
# 100,900
# 17,000
# 62,600
# 16,500
# 9,200
# ...

# %%
import csv
f = open(r"C:\Users\USER\python3ex\card.csv", encoding='utf-8') #r은 "백슬래시 그대로 읽어줘" 라는 뜻
data = csv.reader(f)
next(data)
data = list(data)
for row in data:
    print(row[6])
f.close()

# %%
#CSV 파일에서 읽어 들인 데이터는 모두 문자로 인식됩니다.

# %%
import csv
f = open(r"C:\Users\USER\python3ex\card.csv", encoding='utf-8') #r은 "백슬래시 그대로 읽어줘" 라는 뜻
data = csv.reader(f)
next(data)
data = list(data)
for row in data:
    payment = int(row[6].replace(',', '')) # 이렇게 쉼표 없어야 숫자로 읽음
    print(payment, type(payment))
f.close()
# Out:
# 546800 <class 'int'>
# 60440 <class 'int'>
# 91520 <class 'int'>
# 89810 <class 'int'>
# 33600 <class 'int'>
# 309600 <class 'int'>
# 61983 <class 'int'>
# 31600 <class 'int'>
# 97000 <class 'int'>
# 96000 <class 'int'>
# 4200 <class 'int'>
# 4200 <class 'int'>
# 75000 <class 'int'>
# 26410 <class 'int'>
# 12500 <class 'int'>
# 1300 <class 'int'>
# 19000 <class 'int'>
# 55995 <class 'int'>
# 118000 <class 'int'>
# 269000 <class 'int'>
# 251000 <class 'int'>
# 75600 <class 'int'>
# 61800 <class 'int'>
# 40900 <class 'int'>
# 4400 <class 'int'>
# 10000 <class 'int'>
# 21400 <class 'int'>
# 63000 <class 'int'>
# 207000 <class 'int'>
# 48000 <class 'int'>
# 23200 <class 'int'>
# 23100 <class 'int'>
# 10000 <class 'int'>
# 50000 <class 'int'>
# 5300 <class 'int'>
# 3990 <class 'int'>
# 11900 <class 'int'>
# 112845 <class 'int'>
# 161598 <class 'int'>
# 16241 <class 'int'>
# 19000 <class 'int'>
# 28500 <class 'int'>
# 4000 <class 'int'>
# 7000 <class 'int'>
# 66046 <class 'int'>
# ...

# %%
import csv
f = open(r"C:\Users\USER\python3ex\card.csv", encoding='utf-8')
data = csv.reader(f)
next(data)
data = list(data)
for row in data:
    if row[-1] == '전표매입':
        print('구매확정!')
    else:
        print('구매취소!')
f.close()
# Out:
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매취소!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매확정!
# 구매취소!
# 구매확정!
# ...

# %%
# 3개월간 카드를 얼마나 사용했는지 총 지출액을 구해 보겠습니다.
#<프로그램 흐름>
#1. 총 지출액을 저장할 변수(spend)를 만들고 초깃값 0 저장하기
#2. 전체 이용내역(data)의 처음부터 마지막까지 반복하기
#2.1 이용금액(data[n][-3])만 골라 정수형으로 변환한 후 총 지출액(spend)에 더하기
#2.2 매입상태가 ‘전표매입’인 건에 한해서만 이용금액을 spend에 더해야 합니다

import csv
f = open(r"C:\Users\USER\python3ex\card.csv", encoding='utf-8')
data = csv.reader(f)
next(data)
data = list(data)
spend = 0
for row in data:
    if row[-1] == '전표매입':
        payment = int(row[-3])
        spend += payment  #전표매입 누적값
    print(spend)
f.close()
# Out:
# 0
# 60440
# 151960
# 241770
# 275370
# 275370
# 275370
# 306970
# 306970
# 402970
# 402970
# 407170
# 482170
# 508580
# 521080
# 522380
# 541380
# 541380
# 659380
# 928380
# 928380
# 928380
# 990180
# 1031080
# 1035480
# 1045480
# 1066880
# 1129880
# 1336880
# 1384880
# 1408080
# 1431180
# 1441180
# 1491180
# 1496480
# 1500470
# 1512370
# 1512370
# 1512370
# 1528611
# 1547611
# 1576111
# 1580111
# 1587111
# 1653157
# 1653157
# 1739457
# 1804357
# 1834357
# 1834357
# 1835857
# 1854557
# 1964667
# 1964667
# 1977315
# 2093015
# 2180515
# 2180615
# 2180615
# 2237115
# 2237115
# 2241815
# 2241815
# 2520415
# 2575615
# 2601615
# 2764695
# 2764695
# 2769695
# 2821695
# 2829525
# 2898025
# 2940045
# 2956845
# 2964945
# 3020145
# 3022445
# 3022445
# 3055445
# 3070945
# 3202645
# 3232645
# 3288645
# 3301845
# 3313345
# 3313345
# 3346045
# 3822781
# 4105834
# 4109909
# 4141389
# 4208839
# 4210439
# 4216339
# 4368769
# 4373069
# 4386969
# 4416569
# 4418069
# 4437869
# 4492469
# 4541469
# ...

# %%
#<프로그램 흐름>
"""
1. 10~12월의 월별 지출액을 저장할 리스트(s_mon)를 만들고 초깃값 0 저장하기
2. 전체 이용내역(data)의 처음부터 마지막까지 반복하기
2.1 각 이용내역에서 매입상태가 '전표매입'이라면
2.1.1 해당 건의 이용월과 이용금액 구하기
2.1.2 이용월에서 10을 빼 월별 지출액 리스트(s_mon)의 인덱스(idx) 구하기
2.1.3 과정 2.1.2에서 구한 인덱스의 값(s_mon[idx])에 과정 2.1.1에서 구한 이용금액 더하기
3. 월별 지출액 리스트(s_mon)로 막대그래프 그리기
"""
# Out:
# "\n1. 10~12월의 월별 지출액을 저장할 리스트(s_mon)를 만들고 초깃값 0 저장하기\n2. 전체 이용내역(data)의 처음부터 마지막까지 반복하기\n2.1 각 이용내역에서 매입상태가 '전표매입'이라면\n2.1.1 해당 건의 이용월과 이용금액 구하기\n2.1.2 이용월에서 10을 빼 월별 지출액 리스트(s_mon)의 인덱스(idx) 구하기\n2.1.3 과정 2.1.2에서 구한 인덱스의 값(s_mon[idx])에 과정 2.1.1에서 구한 이용금액 더하기\n3. 월별 지출액 리스트(s_mon)로 막대그래프 그리기\n"

# %%
a = 100
b = 200
#스와핑
a, b = b, a

print(a,b)
# Out:
# 200 100

# %%
a = 100
b = 200
#스와핑
a, b = 100, 200
b, a = 200, 100
a, b = b, a
print(a,b)
# Out:
# 200 100

# %%
import matplotlib.pyplot as plt

s_mon = [0, 0, 0]
for row in data:
    if row[-1] == '전표매입':
        mon, payment = int(row[0].split('-')[1]), int(row[-3])
        idx = mon - 10
        s_mon[idx] += payment

plt.rc('font', family='Malgun Gothic')
plt.title('10~12월 지출현황')
plt.bar(['10월', '11월', '12월'], s_mon, color='royalblue')
plt.show()

# %%
s_mon = [0, 0, 0]
for row in data:
    if row[-1] == '전표매입':
        mon, payment = int(row[0].split('-')[1]), int(row[-3])
        idx = mon - 10
        s_mon[idx] += payment
print(s_mon)
# Out:
# [2093015, 4127744, 2023269]

# %%
taxi = [0, 0, 0]
for row in data:
    if row[-1] == '전표매입' and '택시' in row[5]:
        mon, payment = int(row[0].split('-')[1]), int(row[-3])
        idx = mon - 10
        taxi[idx] += payment
print(taxi)
# Out:
# [8600, 83900, 52800]

# %%
print(data[0][0])
# Out:
# 2019-10-12 9:13

# %%
plt.rc('font', family='Malgun Gothic')
plt.title('10~12월 택시비 지출현황')
plt. plot(['10월', '11월', '12월'], taxi, color='crimson', label='택시비 지출액')
plt.legend()
plt.show()

# %%
deli = [0, 0, 0]
for row in data:
    if row[-1] == '전표매입' and row[5] == '(주)우아한형제들':
        mon, payment = int(row[0].split('-')[1]), int(row[-3])
        idx = mon - 10
        deli[idx] += payment
plt.rc('font', family='Malgun Gothic')
plt.title('10~12월 배달음식비 지출현황')
plt. plot(['10월', '11월', '12월'], deli, color='indigo', label='배달음식비 지출액')
plt.legend()
plt.show()

# %%
plt.title('10~12월 택시비/배달음식비 지출현황')
plt. plot(['10월', '11월', '12월'], taxi, color='crimson', label='택시비 지출액')
plt. plot(['10월', '11월', '12월'], deli, color='indigo', label='배달음식비 지출액')
plt.legend()
plt.show()

# %%
#<프로그램 흐름>
"""
1. 가맹점별 지출액을 저장할 빈 딕셔너리(spending) 만들기

2. 전체 이용내역(data)의 처음부터 마지막까지 반복하기

2.1 각 이용내역에서 매입상태가 '전표매입'이라면

2.1.1 해당 건의 가맹점명(store)과 이용금액(payment) 구하기

2.1.2 만약 딕셔너리의 키에 해당 가맹점명(store)이 없다면

2.1.2.1 가맹점명(store)을 키로, 이용금액(payment)을 값으로 하는 요소 추가하기

2.1.3 만약 딕셔너리의 키에 해당 가맹점명(store)이 있다면

2.1.3.1 해당 요소에 이용금액(payment) 더하기

3. 값(payment)을 기준으로 완성된 딕셔너리(spending)를 내림차순 정렬한 다음, 앞에서 10개 요소 뽑기

4. 지출액 상위 10개의 가맹점명과 지출액(spending의 키와 값)을 각각 리스트에 저장하기

5. 가맹점명 리스트와 지출액 리스트로 막대그래프 그리기
"""

# %%
spending = {}
for row in data:
    if row[-1] == '전표매입':
        store, payment = row[-4], int(row[-3])
        if store not in spending.keys(): #딕셔너리에 넣어
            spending[store] = payment #키가 없으면 새로 만들고
        else:
            spending[store] += payment #키가 있으면 누적
print(spending)
# Out:
# {'GS  샵': 60440, 'G마켓': 201630, '11번가': 151010, '네이버파이낸셜(주)': 1395840, '(주)에이랜드 타임스퀘어': 31600, '(주)곱': 96000, '카카오페이(택시)': 78000, '포도당': 75000, '에뛰드': 26410, '미니스톱목동파라곤점': 1300, '(주)우아한형제들': 361430, '스패뉴시청지점': 61800, '티머니 개인택시': 27300, '스타벅스코리아': 100000, '전화결제': 207000, '케이데코(K Deco)': 48000, '씨제이올리브영(주)합정메세나폴': 23200, '타르타르홍대점': 23100, '더본내과의원': 159800, '나폴레옹과자점': 52600, '홈플러스익스프레스신정3점': 3990, '롯데E커머스': 16241, '(주)에스쁘아': 28500, '(주)현대백화점목동점': 415502, 'SSG.COM': 260259, 'GS25 문래미원점': 1500, '(주)라크라센타본점': 18700, '크로키닷컴': 299610, '(주)이랜드월드영등포타임스퀘어': 100, '빠레뜨한남': 56500, '(주)신세계백화점강남점': 333800, '(주)엔터식스패션쇼핑몰 강남점': 26000, '어반플랜트': 57000, '곤트란쉐리에 합정점': 7830, '(주)갈라인터내셔널': 68500, '씨제이올리브영(주)신세계': 42020, '카페마마스타임스퀘어점': 64400, '조아약국': 2300, '씨유목동11단지점': 14200, '(주)이마트  목동점': 305690, '스마일페이 (신라면세점)': 978035, '(주)디지탈명성텍': 4075, 'CU 오목교스퀘어점': 1600, '써브웨이 오목교점': 5900, '갤러리아명품관식품': 18200, '씨제이올리브영(주) 목동역점': 29600, '파리바게뜨 (양천구청점)': 3000, '(주)다른코스메틱스': 29000, '이유': 285000, '씨제이올리브영(주) 목동': 9200, '주식
# ...

# %%
import operator
import matplotlib.pyplot as plt

spending = {}
for row in data:
    if row[-1] == '전표매입':
        store, payment = row[-4], int(row[-3])
        if store not in spending.keys():
            spending[store] = payment
        else:
            spending[store] += payment

top10 = sorted(spending.items(), key=operator.itemgetter(1), reverse=True)[:10]
top10_store, top10_amount = [], []
for t in top10:
    top10_store.append(t[0])
    top10_amount.append(t[1])
plt.rc('font', family='Malgun Gothic')
plt.title('10~12월 지출 TOP 10')
plt.barh(top10_store, top10_amount, color='b')
plt.show()

# %%
#함수 기본 153 페이지
def ggg():
    print("함수ggg()")

ggg()
ggg()
# Out:
# 함수ggg()
# 함수ggg()

# %%
def ggg2(x, y):
    print(x, y)

#ggg2()
ggg2(100, True)
ggg2("가나다", 30)
# Out:
# 100 True
# 가나다 30

# %%
def ggg3(x, y):
    #어떤 실행
    z = x * y
    return z

val = ggg3(100, 200)
print(val)
val = ggg3(3, 5)
print(val)
# Out:
# 20000
# 15

# %%
from tkinter import * #Tkinter 윈도우창 만드는 법
root = Tk()
root.title('나의 윈도우')
root.geometry('400x200+800+300') 
#해상도에 따라 pixel 값이 달라질 수 있음. 앞의 숫자는 옆으로 늘어나는 것이고
#세번째 값은 왼쪽에서 얼마나 떨어지는지
#마지막 값은 위에서 얼마나 떨어지는지
root.resizable(False, True) #Resizing 가능
label1 = Label(root, text='절대위치 x = 200, y = 100')
label1.place(x=200, y=100)

root.mainloop() #내가 셋팅한 것이 모두 나오게 하려면 Mainloop가 맨 마지막에 있어야 함.

# %%
from tkinter import *
root = Tk()
root.title('나의 윈도우')
root.geometry('400x200+800+300')
root.resizable(False, True)
label1 = Label(root, text='절대위치 x = 200, y = 100')
label1.place(x=200, y=100)
root.mainloop()

# %%
root = Tk()
root.title('나의 윈도우')
root.geometry('400x200')

label1 = Label(root, text='안녕하세요!', relief='groove')
label1.pack()
label2 = Label(root, text='Hello!', relief='groove')
label2.pack()
label3 = Label(root, text='니하오!', relief='groove')
label3.pack()
label4 = Label(root, text='봉쥬르!', relief='groove')
label4.pack()

root.mainloop()

# %%
root = Tk()
root.title('나의 윈도우')
root.geometry('400x200')

label1 = Label(root, text='안녕하세요!', relief='groove')
label1.pack(side='left')
label2 = Label(root, text='Hello!', relief='groove')
label2.pack(side='right')
label3 = Label(root, text='니하오!', relief='groove')
label3.pack(side='top')
label4 = Label(root, text='봉쥬르!', relief='groove')
label4.pack(side='bottom')

root.mainloop()

# %%
root = Tk()
root.title('나의 윈도우')
root.geometry('400x200')

label1 = Label(root, text='안녕하세요!', relief='groove')
label1.grid(row=0, column=0)
label2 = Label(root, text='Hello!', relief='groove')
label2.grid(row=0, column=1)
label3 = Label(root, text='니하오!', relief='groove')
label3.grid(row=1, column=0)
label4 = Label(root, text='봉쥬르!', relief='groove')
label4.grid(row=1, column=1)

root.mainloop()

# %%
#이벤트 만들기

def sayhello():                  #함수1
    txt.set('Hello!! ' * 3)

def cleartext():                 #함수2
    txt.set('')

from tkinter import *
root = Tk()
root.title('나의 윈도우')
root.geometry('400x200+800+300')
root.resizable(False, False)

txt = StringVar()   #동적변수

lbl1 = Label(root, textvariable = txt, width = 40)
lbl1.grid(row=0, column=0)
btn1 = Button(root, text='확인', width=10, command=sayhello)
btn1.grid(row=0, column=1)
btn2 = Button(root, text='지우기', width=10, command=cleartext)
btn2.grid(row=1, column=1)

root.mainloop()
